# %% [markdown]
# <a href="https://colab.research.google.com/github/tamapi/test_001/blob/master/test_002_packages_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Google Colabでインストールされているパッケージの確認

print('Hello, World! ---5---')
import pip
print('Hello, World! ---52---')
from pip._internal.utils.misc import get_installed_distributions
print('Hello, World! ---53---')
#from pip import get_installed_distributions
installed_packages = get_installed_distributions()
installed_packages_list = sorted(["%s==%s" % (i.key, i.version)
     for i in installed_packages])
print(len(installed_packages_list))
print(installed_packages_list)

for num in range(0, len(installed_packages_list)):
    print(str(num) + "     " + installed_packages_list[num])
# Out:
# Hello, World! ---5---
# Hello, World! ---52---
# Hello, World! ---53---
# 413
# ...
